# %%
import pandas as pd
df_list = [pd.read_csv('/content/drive/MyDrive/SOC/Data/AgEvidence/cover crops/cover_crops0.csv')]
df = pd.concat(df_list, axis = 0)
df
# Out:
#           review                                                 rv rvYear  \
# 0    Cover Crops                                       total carbon    1;2
# 1    Cover Crops                                       total carbon    1;2
# 2    Cover Crops                                       total carbon    1;2
# 3    Cover Crops                                       total carbon    1;2
# 4    Cover Crops                                       total carbon    1;2
# ..           ...                                                ...    ...
# 393  Cover Crops  cumulative nitrous oxide flux from soil April ...      1
# 394  Cover Crops  cumulative nitrous oxide flux from soil April ...      2
# 395  Cover Crops  cumulative nitrous oxide flux from soil April ...      2
# 396  Cover Crops  cumulative nitrous oxide flux from soil April ...      2
# 397  Cover Crops  cumulative nitrous oxide flux from soil April ...      2
#
#            rvUnits  startYear  studyLength sampleDepth  controlValue  \
# 0            Mg/ha       2011            2     0-60 cm          1.01
# 1            Mg/ha       2011            2     0-60 cm          1.01
# 2            Mg/ha       2011            2     0-60 cm          1.01
# 3            Mg/ha       2011            2     0-60 cm          1.09
# 4            Mg/ha       2011            2     0-60 cm          1.09
# ..             ...        ...          ...         ...           ...
# 393  kg N~2~O-N/ha       2003            2         NaN          0.30
# 394  kg N~2~O-N/ha       2003            2         NaN          6.96
# 395  kg N~2~O-N/ha       2003            2         NaN          8.21
# 396  kg N~2~O-N/ha       2003            2         NaN         11.30
# 397  kg N~2~O-N/ha       2003            2         NaN          2.41
#
#      trtValue  percentChange  ...              Type of Species  \
# 0        1.01           0.00  ...                   Non-legume
# 1        1.01           0.00  ...           Non-legume Mixture
# 2        1.01           0.00  ...  Non-legume + Legume Mixture
# 3        1.09           0.00  ...                   Non-legume
# 4        1.09           0.00  ...           Non-legume Mixture
# ..        ...            ...  ...                          ...
# 393      0.31           3.33  ...                   Non-legume
# 394      2.14         -69.25  ...                   Non-legume
# 395      3.49         -57.49  ...                   Non-legume
# 396     15.40          36.28  ...                   Non-legume
# 397      7.33         204.15  ...                   Non-legume
#
#     Soil Sample Depth                         doi  \
# 0             0-60 cm  10.1016/j.agee.2015.10.014
# 1             0-60 cm  10.1016/j.agee.2015.10.014
# 2             0-60 cm  10.1016/j.agee.2015.10.014
# 3             0-60 cm  10.1016/j.agee.2015.10.014
# 4             0-60 cm  10.1016/j.agee.2015.10.014
# ..                ...                         ...
# 393      Not measured        10.2134/jeq2005.0183
# 394      Not measured        10.2134/jeq2005.0183
# 395      Not measured        10.2134/jeq2005.0183
# 396      Not measured        10.2134/jeq2005.0183
# 397      Not measured        10.2134/jeq2005.0183
#
#                                                  title  \
# 0    Using cover crops in headlands of organic grai...
# 1    Using cover crops in headlands of organic grai...
# 2    Using cover crops in headlands of organic grai...
# 3    Using cover crops in headlands of organic grai...
# 4    Using cover crops in headlands of organic grai...
# ..                                                 ...
# 393  Nitrous oxide emissions from corn-soybean syst...
# 394  Nitrous oxide emissions from corn-soybean syst...
# 395  Nitrous oxide emissions from corn-soybean syst...
# 396  Nitrous oxide emissions from corn-soybean syst...
# 397  Nitrous oxide emissions from corn-soybean syst...
#
#                                                authors   authors_abbrev  \
# 0    Welch, R.Y., Behnke, G.D., Davis, A.S., Masiun...     Welch et al.
# 1    Welch, R.Y., Behnke, G.D., Davis, A.S., Masiun...     Welch et al.
# 2    Welch, R.Y., Behnke, G.D., Davis, A.S., Masiun...     Welch et al.
# 3    Welch, R.Y., Behnke, G.D., Davis, A.S., Masiun...     Welch et al.
# 4    Welch, R.Y., Behnke, G.D., Davis, A.S., Masiun...     Welch et al.
# ..                                                 ...              ...
# 393                       Parkin, T.B., & Kaspar, T.C.  Parkin & Kaspar
# 394                       Parkin, T.B., & Kaspar, T.C.  Parkin & Kaspar
# 395                       Parkin, T.B., & Kaspar, T.C.  Parkin & Kaspar
# 396                       Parkin, T.B., & Kaspar, T.C.  Parkin & Kaspar
# 397                       Parkin, T.B., & Kaspar, T.C.  Parkin & Kaspar
#
#     pubyear                                  journal volume_issue      pages
# 0      2016  Agriculture, Ecosystems and Environment          216    322-332
# 1      2016  Agriculture, Ecosystems and Environment          216    322-332
# 2      2016  Agriculture, Ecosystems and Environment          216    322-332
# 3      2016  Agriculture, Ecosystems and Environment          216    322-332
# 4      2016  Agriculture, Ecosystems and Environment          216    322-332
# ..      ...                                      ...          ...        ...
# 393    2006         Journal of Environmental Quality        35(4)  1496-1506
# 394    2006         Journal of Environmental Quality        35(4)  1496-1506
# 395    2006         Journal of Environmental Quality        35(4)  1496-1506
# 396    2006         Journal of Environmental Quality        35(4)  1496-1506
# 397    2006         Journal of Environmental Quality        35(4)  1496-1506
#
# [398 rows x 23 columns]

# %%
df.rv = df.rv.str.lower()

# %%
df = df.query('rv.str.contains("soil") and rv.str.contains("organic") and rv.str.contains("carbon") and not rv.str.contains("poc") and not rv.str.contains("particulate")', engine='python')

# %%
df.rv.value_counts()
# Out:
# soil organic carbon concentration                                 29
# soil organic carbon                                               12
# soil organic carbon (0-75 cm)                                      9
# soil organic carbon (0-15 cm)                                      9
# soil organic carbon (15-75 cm)                                     9
# soil organic carbon in soybean (5-15 cm soil depth)                8
# soil organic carbon in soybean (0-5 cm soil depth)                 7
# soil organic carbon, corn for grain                                4
# soil organic carbon after controlling for clay content             4
# soil organic carbon, corn for silage                               4
# soil organic carbon (0-5 cm depth)                                 4
# soil organic carbon in topsoil                                     3
# soil organic carbon 0-30 cm depth (spring)                         1
# soil organic carbon (0-10 cm depth)                                1
# soil organic carbon (10-20 cm depth)                               1
# soil organic carbon (20-40 cm depth)                               1
# soil organic carbon (40-60 cm depth)                               1
# soil organic carbon in corn (0-5 cm soil depth)                    1
# soil organic carbon (soc), spring sample (0-60 cm depth)           1
# soil organic carbon (soc) in fall following cover crop, 0-15cm     1
# Name: rv, dtype: int64

# %%
df.rvUnits.value_counts()
# Out:
# g/kg                   38
# Mt/ha/layer/1 m/1 m    27
# %                      24
# Mg C/ha                 8
# g/kg soil               5
# mg/g soil               4
# Mt/ha/yr                3
# Mg/ha                   1
# Name: rvUnits, dtype: int64

# %% [markdown]
# Convert Units

# %%
# change all g/kg variants to g/kg
units = list(df.rvUnits)
for i in range(len(units)):
    if "/kg" in units[i]:
        units[i] = "g/kg"

# df.rvUnits = units
# df.rvUnits.value_counts()

# %%
# change to percent
control_values = list(df.controlValue)
for i in range(len(units)):
    # g/100 g and % are already in percent
    if units[i] == "g/kg":
        control_values[i] *= 0.1

# df.controlValue = control_values

# %%
df.columns
# Out:
# Index(['review', 'rv', 'rvYear', 'rvUnits', 'startYear', 'studyLength',
#        'sampleDepth', 'controlValue', 'trtValue', 'percentChange', 'norm',
#        'Duration of Study', 'Number of Species', 'Type of Species',
#        'Soil Sample Depth', 'doi', 'title', 'authors', 'authors_abbrev',
#        'pubyear', 'journal', 'volume_issue', 'pages'],
#       dtype='object')

# %%
feature_cols = [
    "rvUnits",
    "controlValue",
    "Type of Species",
    "Number of Species",
    "sampleDepth",
    "studyLength",
    "startYear",
    "norm"
]

# %%
X = df[feature_cols]
y = df['percentChange']

# %%
X.isnull().sum()
# Out:
# rvUnits              0
# controlValue         0
# Type of Species      0
# Number of Species    0
# sampleDepth          0
# studyLength          0
# startYear            0
# norm                 0
# dtype: int64

# %%
X.sampleDepth.value_counts()
# Out:
# 0-30 cm     83
# 0-60 cm     18
# 0-100 cm     9
# Name: sampleDepth, dtype: int64

# %%
X
# Out:
#        rvUnits  controlValue Type of Species Number of Species sampleDepth  \
# 18        g/kg          36.4      Non-legume    Single species     0-30 cm
# 19   g/kg soil          15.6      Non-legume    Single species     0-30 cm
# 20   g/kg soil          26.9      Non-legume    Single species     0-30 cm
# 21   g/kg soil          23.9      Non-legume    Single species     0-30 cm
# 22   g/kg soil          26.9      Non-legume    Single species     0-30 cm
# ..         ...           ...             ...               ...         ...
# 166    Mg C/ha          38.8      Non-legume    Single species     0-30 cm
# 167    Mg C/ha          27.0      Non-legume    Single species     0-30 cm
# 168    Mg C/ha          27.0      Non-legume    Single species     0-30 cm
# 169    Mg C/ha          37.4      Non-legume    Single species     0-30 cm
# 170    Mg C/ha          37.4      Non-legume    Single species     0-30 cm
#
#      studyLength  startYear  norm
# 18             1       2008     2
# 19             2       2003     2
# 20             3       2014     2
# 21             3       2014     2
# 22             3       2014     2
# ..           ...        ...   ...
# 166            4       2014     2
# 167            4       2014     2
# 168            4       2014     2
# 169            4       2014     2
# 170            4       2014     2
#
# [110 rows x 8 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
to_encode = ["Type of Species", "Number of Species", "sampleDepth", "rvUnits"]

X[to_encode] = encoder.fit_transform(X[to_encode])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
X
# Out:
#      rvUnits  controlValue  Type of Species  Number of Species  sampleDepth  \
# 18       5.0          36.4              0.0                0.0          1.0
# 19       6.0          15.6              0.0                0.0          1.0
# 20       6.0          26.9              0.0                0.0          1.0
# 21       6.0          23.9              0.0                0.0          1.0
# 22       6.0          26.9              0.0                0.0          1.0
# ..       ...           ...              ...                ...          ...
# 166      1.0          38.8              0.0                0.0          1.0
# 167      1.0          27.0              0.0                0.0          1.0
# 168      1.0          27.0              0.0                0.0          1.0
# 169      1.0          37.4              0.0                0.0          1.0
# 170      1.0          37.4              0.0                0.0          1.0
#
#      studyLength  startYear  norm
# 18             1       2008     2
# 19             2       2003     2
# 20             3       2014     2
# 21             3       2014     2
# 22             3       2014     2
# ..           ...        ...   ...
# 166            4       2014     2
# 167            4       2014     2
# 168            4       2014     2
# 169            4       2014     2
# 170            4       2014     2
#
# [110 rows x 8 columns]

# %%
X.fillna(0, inplace = True)
X.isnull().sum()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# rvUnits              0
# controlValue         0
# Type of Species      0
# Number of Species    0
# sampleDepth          0
# studyLength          0
# startYear            0
# norm                 0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
preds = dt.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, preds, squared = False)
# Out:
# 11.975325599510258

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators = 500)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
preds = rf.predict(X_test)
mean_squared_error(y_test, preds, squared = False)
# Out:
# 11.036317817857816

# %%
df.groupby(['Type of Species', 'Number of Species']).agg({'percentChange': ['mean']})
# Out:
#                                           percentChange
#                                                    mean
# Type of Species         Number of Species
# Non-legume              Single species         2.172344
# Rotation of Cover Crops Single species         1.951304
