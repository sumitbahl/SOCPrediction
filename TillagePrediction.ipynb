# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/SOC/Data/AgEvidence/tillage.csv')
df
# Out:
#        review                                        rv          rvYear  \
# 0     Tillage  soil organic carbon by weight mid-season               1
# 1     Tillage  soil organic carbon by weight mid-season               2
# 2     Tillage  soil organic carbon by weight mid-season               3
# 3     Tillage  soil organic carbon by weight mid-season               4
# 4     Tillage  soil organic carbon by weight mid-season               1
# ...       ...                                       ...             ...
# 1583  Tillage        fertilizer induced emission factor              40
# 1584  Tillage        fertilizer induced emission factor              41
# 1585  Tillage        fertilizer induced emission factor              41
# 1586  Tillage        fertilizer induced emission factor              41
# 1587  Tillage    greenhouse gas intensity (N~2~O/grain)  10;11;12;13;14
#
#                    rvUnits  startYear  studyLength sampleDepth  controlValue  \
# 0                  g/100 g       1989            4     0-30 cm          1.08
# 1                  g/100 g       1989            4     0-30 cm          1.15
# 2                  g/100 g       1989            4     0-30 cm          1.21
# 3                  g/100 g       1989            4     0-30 cm          1.28
# 4                  g/100 g       1989            4     0-30 cm          1.08
# ...                    ...        ...          ...         ...           ...
# 1583                     %       1975           41         NaN          0.32
# 1584                     %       1975           41         NaN          0.78
# 1585                     %       1975           41         NaN          0.78
# 1586                     %       1975           41         NaN          0.78
# 1587  kg N~2~O/Mg DM grain       2002           14         NaN          0.36
#
#       trtValue  percentChange  ...             treatment   sampledepth  \
# 0         1.53          41.67  ...  Conservation tillage       0-30 cm
# 1         1.56          35.65  ...  Conservation tillage       0-30 cm
# 2         1.54          27.27  ...  Conservation tillage       0-30 cm
# 3         1.52          18.75  ...  Conservation tillage       0-30 cm
# 4         1.75          62.04  ...            No tillage       0-30 cm
# ...        ...            ...  ...                   ...           ...
# 1583      0.45           0.13  ...            No tillage  Not measured
# 1584      0.91           0.13  ...  Conservation tillage  Not measured
# 1585      0.54          -0.24  ...         Zonal tillage  Not measured
# 1586      0.84           0.06  ...            No tillage  Not measured
# 1587      0.30         -16.67  ...            No tillage  Not measured
#
#                             doi  \
# 0     10.1080/00103629409369033
# 1     10.1080/00103629409369033
# 2     10.1080/00103629409369033
# 3     10.1080/00103629409369033
# 4     10.1080/00103629409369033
# ...                         ...
# 1583    10.2134/jeq2018.05.0188
# 1584    10.2134/jeq2018.05.0188
# 1585    10.2134/jeq2018.05.0188
# 1586    10.2134/jeq2018.05.0188
# 1587          10.1111/gcb.13637
#
#                                                   title  \
# 0     Tillage effects on selected chemical propertie...
# 1     Tillage effects on selected chemical propertie...
# 2     Tillage effects on selected chemical propertie...
# 3     Tillage effects on selected chemical propertie...
# 4     Tillage effects on selected chemical propertie...
# ...                                                 ...
# 1583  Tillage and nitrogen source impacts on relatio...
# 1584  Tillage and nitrogen source impacts on relatio...
# 1585  Tillage and nitrogen source impacts on relatio...
# 1586  Tillage and nitrogen source impacts on relatio...
# 1587  Long-term no-till and stover retention each de...
#
#                                                 authors authors_abbrev  \
# 0     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...   Kitur et al.
# 1     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...   Kitur et al.
# 2     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...   Kitur et al.
# 3     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...   Kitur et al.
# 4     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...   Kitur et al.
# ...                                                 ...            ...
# 1583                          Omonode, R.E. & Vyn, T.J.  Omonode & Vyn
# 1584                          Omonode, R.E. & Vyn, T.J.  Omonode & Vyn
# 1585                          Omonode, R.E. & Vyn, T.J.  Omonode & Vyn
# 1586                          Omonode, R.E. & Vyn, T.J.  Omonode & Vyn
# 1587  Jin, V.L., Schmer, M.R., Stewart, C.E., Sindel...     Jin et al.
#
#      pubyear                                            journal volume_issue  \
# 0       1994  Communications in Soil Science and Plant Analysis           25
# 1       1994  Communications in Soil Science and Plant Analysis           25
# 2       1994  Communications in Soil Science and Plant Analysis           25
# 3       1994  Communications in Soil Science and Plant Analysis           25
# 4       1994  Communications in Soil Science and Plant Analysis           25
# ...      ...                                                ...          ...
# 1583    2019                   Journal of Environmental Quality           48
# 1584    2019                   Journal of Environmental Quality           48
# 1585    2019                   Journal of Environmental Quality           48
# 1586    2019                   Journal of Environmental Quality           48
# 1587    2017                              Global Change Biology        23(7)
#
#           pages
# 0       225-246
# 1       225-246
# 2       225-246
# 3       225-246
# 4       225-246
# ...         ...
# 1583    421-429
# 1584    421-429
# 1585    421-429
# 1586    421-429
# 1587  2848-2862
#
# [1588 rows x 23 columns]

# %%
df.rv = df.rv.str.lower()

# %%
df = df.query('rv.str.contains("soil") and rv.str.contains("organic") and rv.str.contains("carbon") and not rv.str.contains("poc") and not rv.str.contains("particulate")', engine='python')

# %%
df.rv.value_counts()
# Out:
# soil organic carbon stock averaged across three crop rotations    252
# soil organic carbon concentration                                 209
# soil organic carbon reserves                                       81
# total soil organic carbon                                          78
# soil organic carbon                                                78
# soil organic carbon content                                        60
# soil total organic carbon                                          24
# cumulative stock of soil organic carbon                            24
# soil organic carbon by weight mid-season                           24
# soil organic carbon concentration in spring                        24
# soil organic carbon stocks                                         20
# change in soil organic carbon concentrations                       18
# soil organic carbon storage in the spring                          16
# soil organic carbon concentration on an area basis                 12
# soil organic carbon concentration on a mass basis                  10
# mass of soil organic carbon                                         7
# soil organic carbon on area basis                                   6
# soil organic carbon stock                                           4
# weighted soil organic carbon                                        4
# soil organic carbon pool, c3                                        4
# soil organic carbon pool, c4                                        4
# total soil organic carbon pool in soil                              4
# soil organic carbon pool                                            4
# soil organic carbon in march                                        4
# soil organic carbon contents                                        4
# half-life of c-soil organic carbon                                  4
# soil organic carbon, initial soc content                            3
# soil organic carbon derived from corn root and shoot biomass        2
# soil organic carbon storage after harvest                           2
# soil organic carbon derived from corn root biomass                  2
# soil organic carbon concentration (after harvest                    2
# soil organic carbon content in wooster silt loam after harvest      2
# soil organic carbon content in crosby silt loam after harvest       2
# equivalent mass of soil organic carbon                              1
# soil organic carbon stock (c3-c) in topsoil                         1
# Name: rv, dtype: int64

# %%
df.rvUnits.value_counts()
# Out:
# Mg/ha               500
# g/kg                181
# g C/kg              121
# Mg C/ha              81
# g C/kg soil          28
# g/100 g              24
# Mg C/ha in depth     20
# %                    18
# g/kg soil             9
# t/ha                  8
# kg/m^2^               4
# kg C/ha               1
# kg/ha                 1
# Name: rvUnits, dtype: int64

# %% [markdown]
# Convert Units

# %%
# change all g/kg variants to g/kg
units = list(df.rvUnits)
for i in range(len(units)):
    if "/kg" in units[i]:
        units[i] = "g/kg"

# df.rvUnits = units
# df.rvUnits.value_counts()

# %%
# change to percent
control_values = list(df.controlValue)
for i in range(len(units)):
    # g/100 g and % are already in percent
    if units[i] == "g/kg":
        control_values[i] *= 0.1

# df.controlValue = control_values

# %%
df
# Out:
#        review                                                 rv rvYear  \
# 0     Tillage           soil organic carbon by weight mid-season      1
# 1     Tillage           soil organic carbon by weight mid-season      2
# 2     Tillage           soil organic carbon by weight mid-season      3
# 3     Tillage           soil organic carbon by weight mid-season      4
# 4     Tillage           soil organic carbon by weight mid-season      1
# ...       ...                                                ...    ...
# 1155  Tillage  soil organic carbon stock averaged across thre...      0
# 1156  Tillage  soil organic carbon stock averaged across thre...      0
# 1157  Tillage  soil organic carbon stock averaged across thre...      0
# 1158  Tillage  soil organic carbon stock averaged across thre...      0
# 1159  Tillage  soil organic carbon stock averaged across thre...      0
#
#       rvUnits  startYear  studyLength sampleDepth  controlValue  trtValue  \
# 0     g/100 g       1989            4     0-30 cm          1.08      1.53
# 1     g/100 g       1989            4     0-30 cm          1.15      1.56
# 2     g/100 g       1989            4     0-30 cm          1.21      1.54
# 3     g/100 g       1989            4     0-30 cm          1.28      1.52
# 4     g/100 g       1989            4     0-30 cm          1.08      1.75
# ...       ...        ...          ...         ...           ...       ...
# 1155    Mg/ha       2002           13     0-60 cm        158.86    158.86
# 1156    Mg/ha       2002           13     0-60 cm        158.86    158.86
# 1157    Mg/ha       2002           13     0-60 cm        158.86    158.86
# 1158    Mg/ha       2002           13     0-60 cm        158.86    158.86
# 1159    Mg/ha       2002           13     0-60 cm        158.86    158.86
#
#       percentChange  ...             treatment sampledepth  \
# 0             41.67  ...  Conservation tillage     0-30 cm
# 1             35.65  ...  Conservation tillage     0-30 cm
# 2             27.27  ...  Conservation tillage     0-30 cm
# 3             18.75  ...  Conservation tillage     0-30 cm
# 4             62.04  ...            No tillage     0-30 cm
# ...             ...  ...                   ...         ...
# 1155           0.00  ...  Conservation tillage     0-60 cm
# 1156           0.00  ...            No tillage     0-60 cm
# 1157           0.00  ...            No tillage     0-60 cm
# 1158           0.00  ...         Zonal tillage     0-60 cm
# 1159           0.00  ...         Zonal tillage     0-60 cm
#
#                             doi  \
# 0     10.1080/00103629409369033
# 1     10.1080/00103629409369033
# 2     10.1080/00103629409369033
# 3     10.1080/00103629409369033
# 4     10.1080/00103629409369033
# ...                         ...
# 1155         10.1002/saj2.20003
# 1156         10.1002/saj2.20003
# 1157         10.1002/saj2.20003
# 1158         10.1002/saj2.20003
# 1159         10.1002/saj2.20003
#
#                                                   title  \
# 0     Tillage effects on selected chemical propertie...
# 1     Tillage effects on selected chemical propertie...
# 2     Tillage effects on selected chemical propertie...
# 3     Tillage effects on selected chemical propertie...
# 4     Tillage effects on selected chemical propertie...
# ...                                                 ...
# 1155  Quantifying soil carbon change in a long-term ...
# 1156  Quantifying soil carbon change in a long-term ...
# 1157  Quantifying soil carbon change in a long-term ...
# 1158  Quantifying soil carbon change in a long-term ...
# 1159  Quantifying soil carbon change in a long-term ...
#
#                                                 authors  \
# 0     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...
# 1     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...
# 2     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...
# 3     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...
# 4     Kitur, B.K., Phillips, S.R., Olson, K.R., & Eb...
# ...                                                 ...
# 1155                  Al-Kaisi, M.M., & Kwaw-Mensah, D.
# 1156                  Al-Kaisi, M.M., & Kwaw-Mensah, D.
# 1157                  Al-Kaisi, M.M., & Kwaw-Mensah, D.
# 1158                  Al-Kaisi, M.M., & Kwaw-Mensah, D.
# 1159                  Al-Kaisi, M.M., & Kwaw-Mensah, D.
#
#               authors_abbrev pubyear  \
# 0               Kitur et al.    1994
# 1               Kitur et al.    1994
# 2               Kitur et al.    1994
# 3               Kitur et al.    1994
# 4               Kitur et al.    1994
# ...                      ...     ...
# 1155  Al-Kaisi & Kwaw-Mensah    2020
# 1156  Al-Kaisi & Kwaw-Mensah    2020
# 1157  Al-Kaisi & Kwaw-Mensah    2020
# 1158  Al-Kaisi & Kwaw-Mensah    2020
# 1159  Al-Kaisi & Kwaw-Mensah    2020
#
#                                                 journal volume_issue    pages
# 0     Communications in Soil Science and Plant Analysis           25  225-246
# 1     Communications in Soil Science and Plant Analysis           25  225-246
# 2     Communications in Soil Science and Plant Analysis           25  225-246
# 3     Communications in Soil Science and Plant Analysis           25  225-246
# 4     Communications in Soil Science and Plant Analysis           25  225-246
# ...                                                 ...          ...      ...
# 1155            Soil Science Society of America Journal           84  182-202
# 1156            Soil Science Society of America Journal           84  182-202
# 1157            Soil Science Society of America Journal           84  182-202
# 1158            Soil Science Society of America Journal           84  182-202
# 1159            Soil Science Society of America Journal           84  182-202
#
# [996 rows x 23 columns]

# %%
feature_cols = [
    "control",
    "rvUnits",
    "controlValue",
    "treatment",
    "sampleDepth",
    "studyLength",
    "startYear"
]

# %%
X = df[feature_cols]
y = df['percentChange']

# %%
X.isnull().sum()
# Out:
# control          0
# rvUnits          0
# controlValue     0
# treatment        0
# sampleDepth     38
# studyLength      0
# startYear        0
# dtype: int64

# %%
X.sampleDepth.value_counts()
# Out:
# 0-30 cm     554
# 0-60 cm     353
# 0-100 cm     33
# 0-150 cm     18
# Name: sampleDepth, dtype: int64

# %%
X
# Out:
#                    control  rvUnits  controlValue             treatment  \
# 0     Conventional tillage  g/100 g          1.08  Conservation tillage
# 1     Conventional tillage  g/100 g          1.15  Conservation tillage
# 2     Conventional tillage  g/100 g          1.21  Conservation tillage
# 3     Conventional tillage  g/100 g          1.28  Conservation tillage
# 4     Conventional tillage  g/100 g          1.08            No tillage
# ...                    ...      ...           ...                   ...
# 1155  Conventional tillage    Mg/ha        158.86  Conservation tillage
# 1156  Conventional tillage    Mg/ha        158.86            No tillage
# 1157  Conventional tillage    Mg/ha        158.86            No tillage
# 1158  Conventional tillage    Mg/ha        158.86         Zonal tillage
# 1159  Conventional tillage    Mg/ha        158.86         Zonal tillage
#
#      sampleDepth  studyLength  startYear
# 0        0-30 cm            4       1989
# 1        0-30 cm            4       1989
# 2        0-30 cm            4       1989
# 3        0-30 cm            4       1989
# 4        0-30 cm            4       1989
# ...          ...          ...        ...
# 1155     0-60 cm           13       2002
# 1156     0-60 cm           13       2002
# 1157     0-60 cm           13       2002
# 1158     0-60 cm           13       2002
# 1159     0-60 cm           13       2002
#
# [996 rows x 7 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
to_encode = ["control", "treatment", "sampleDepth", "rvUnits"]

X[to_encode] = encoder.fit_transform(X[to_encode])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
X
# Out:
#       control  rvUnits  controlValue  treatment  sampleDepth  studyLength  \
# 0         0.0      6.0          1.08        0.0          2.0            4
# 1         0.0      6.0          1.15        0.0          2.0            4
# 2         0.0      6.0          1.21        0.0          2.0            4
# 3         0.0      6.0          1.28        0.0          2.0            4
# 4         0.0      6.0          1.08        1.0          2.0            4
# ...       ...      ...           ...        ...          ...          ...
# 1155      0.0      3.0        158.86        0.0          3.0           13
# 1156      0.0      3.0        158.86        1.0          3.0           13
# 1157      0.0      3.0        158.86        1.0          3.0           13
# 1158      0.0      3.0        158.86        2.0          3.0           13
# 1159      0.0      3.0        158.86        2.0          3.0           13
#
#       startYear
# 0          1989
# 1          1989
# 2          1989
# 3          1989
# 4          1989
# ...         ...
# 1155       2002
# 1156       2002
# 1157       2002
# 1158       2002
# 1159       2002
#
# [996 rows x 7 columns]

# %%
X.fillna(0, inplace = True)
X.isnull().sum()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# control         0
# rvUnits         0
# controlValue    0
# treatment       0
# sampleDepth     0
# studyLength     0
# startYear       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
preds = dt.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, preds, squared = False)
# Out:
# 28.62014655417124

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators = 500)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
preds = rf.predict(X_test)
mean_squared_error(y_test, preds, squared = False)
# Out:
# 26.048865127695333

# %%
df.groupby(['control', 'treatment']).agg({'percentChange': ['mean']})
# Out:
#                                           percentChange
#                                                    mean
# control              treatment
# Conventional tillage Conservation tillage      1.711301
#                      No tillage               10.461808
#                      Zonal tillage             6.381040
